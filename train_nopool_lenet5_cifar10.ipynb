# %% [markdown]
# # Train a Simplifed LeNet5 NoPool to classify CIFAR-10 data
#
#
#
# LeNet5 is a well know model which was intruced inpaper "Gradient-based learning applied to document recognitio" by LeCun in1998. In the paer itis ued to classify theMNIST handscripts numbers. Herewe will train asimplified LeNet5 model to clasify CIFAR-10 data.
#
#
#
# # CIFAR-10 dataset
#
# The CIFAR-10 datase consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images nd 10000 test images.
#
# The dataset is divided into fivetrainig batches andone test batch, each with 10000 images. The test batch ontains exactly 1000 randomly-selected images from each class. The training batches contain theremaining mages in random order, but some training batches may contain more images from one clas thananother. Betwen them, the training batches contain exactly 5000 images from each class.
#
#
# Here are the classes in the dataset, as well as 10 random images from each:
#
# ![image.png](attachment:image.png)
#
# For more information, please refer to below link.
#
# http://www.cs.toronto.edu/~kriz/cifar.html
#
# ## Section 1 Define Super Training Parameters
#
# - epoch: define the iteration of the train
# - batch_size: define the train batch size. It depends on how large the memory is. CIFAR-10 is a very small images. 200 - 500 should be good.
# - test_size: define the test batch size.
# - learn rate (lr): The start learn rate for Agagrad
# - keep_prob: the probability of the training parameter
# - augument: To have a better training effect, the image augument is always True

# %%
from cifar10 import cifar10
import os
import tensorflow as tf
import tf_general as tfg
import numpy as np
from train_log import train_log

FLAGS = tf.flags.FLAGS

try:
    #Super parameter definition
    tf.flags.DEFINE_string('f', '', 'kernel')
    tf.flags.DEFINE_integer('epoch', 30000, 'epoch')
    tf.flags.DEFINE_integer('batch_size',500, 'batch size')
    tf.flags.DEFINE_integer('test_size', 500, 'test size')
    tf.flags.DEFINE_float('lr', 0.01, 'learning rate')
    tf.flags.DEFINE_float('drop_rate', 0.3, 'drop out rate for drop lay')
    tf.flags.DEFINE_boolean('augument', True, 'if image augument is applied') 
    #Other training parameter                        
    tf.flags.DEFINE_float('ckpt_frequency', 125, 'frequency to save checkpoint')
    tf.flags.DEFINE_boolean('restore', False, 'restore from checkpoint and run test')
    print('parameters were defined.')
except:
    print('parameters have been defined.')

print("learn Rate =",FLAGS.lr, "drop rate=", FLAGS.drop_rate, " image augument=",FLAGS.augument)   
CONTINUE = 0
RUN = 2
# Out:
# parameters were defined.
# learn Rate = 0.01 drop rate= 0.3  image augument= True

# %% [markdown]
# ## Section 2. Generate Checkpoint dir and Log dir
#
# - Checkpoint dir is saved in variable **../Le-Net5-Log/Le-Net5_CLASS/ckpt_RUN**, if the dir doesn't exist then create it.
# - Log file dir is saved in variable **../Le-Net5-Log/Le-Net5_CLASS/log_RUN**, if the dir doesn't exist then create it.
# - data_path is the position of the CIFAR-10 image data
# The reason to save the model and log outside the project is to avoid effect the git code management.

# %%
ckpt_dir = '../Le-Net5-Log/Le-Net5_NOPOOL/ckpt_'+str(RUN)+'/'
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)

log_dir = '../Le-Net5-Log/Le-Net5_NOPOOL/log_'+str(RUN)+'/'
log = train_log(log_dir)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

data_path = '../cifar-10-batches-py/'
if not os.path.exists(data_path):
    print('The data path doesn\'t exist. Please check if it is a correct data path.')

# %% [markdown]
# ## Section 3. Modified LeNet5
# This is a modified LeNet5 model. A lot of details are ignored in the model.Below is the architecture of the LeNet5 we implemented. It is a little bit different from the original one as some detail design were removed.
#
# ![image.png](attachment:image.png)

# %%
class LeNet5(object):
    def __init__(self, x, n_class=10, drop_rate=0):
        self.input = x
        self.n_class = n_class
        self.drop_rate = drop_rate
        self._build_net()

    def _build_net(self):
        with tf.name_scope('norm'):    
            self.x_norm = tf.nn.l2_normalize(tf.cast(self.input, tf.float32),axis=1)
        
        with tf.name_scope('conv_1'):
            self.conv1 = tfg.conv2d(self.x_norm, 3, 1, 6, 'conv1', 'VALID','RELU')
            print('conv_1: ', self.conv1.get_shape())    
        
        with tf.name_scope('pool_1'):
            self.pool1 = tfg.avg_pool(self.conv1, 1, 1, 'pool1', 'VALID')
            print('pool_1: ', self.pool1.get_shape())
              
        with tf.name_scope('conv_2'):
            self.conv2 = tfg.conv2d(self.pool1, 3, 1, 16, 'conv2', 'VALID','RELU')
            print('conv_2: ', self.conv2.get_shape())
        
        with tf.name_scope('pool_2'):
            self.pool2 = tfg.avg_pool(self.conv2, 1, 1, 'pool2', 'VALID')
            print('pool_2: ', self.pool2.get_shape())   
            
        with tf.name_scope('conv_3'):
            self.conv3 = tfg.conv2d(self.pool2, 3, 1, 120, 'conv3', 'VALID','RELU')
            print('conv_3:', self.conv3.get_shape())
        
        with tf.name_scope('flat_1'):
            self.flat1, self.flat_dim = tfg.flatten(self.conv3)
            print('flat_1:', self.flat1.get_shape())
        
        with tf.name_scope('fc_2'):
            self.fc2 = tfg.fc_layer(self.flat1, self.flat_dim, 840, 'fc2','RELU')
            print('fc_2 ', self.fc2.get_shape())
        
        with tf.name_scope('fc_3'):
            self.fc3 = tfg.fc_layer(self.fc2, 840, 10, 'fc4','RELU')
            print('fc_3: ', self.fc3.get_shape())

        with tf.name_scope('drop_out'):
            self.drop1 = tfg.drop_out(self.fc3, self.drop_rate, 'drop_out')
            print('drop_out: ', self.drop1.get_shape())

        with tf.name_scope('prediction'):
            self.prediction = tf.nn.softmax(self.drop1)
            print('prediction: ', self.prediction.get_shape())

# %% [markdown]
# ## Section 4. Build the calculation graph
#
# ### 4.1 Input layer
#
# Use the data feeder to provide the training data. Therefore we define a placeholder with the same structure of the input data.
# The CIFAR-10 data is 60000 RGB images with each size is 32x32. The data structure should be[batchsize, 32,32,3]. Input channels are 3.

# %%
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None,32,32,3], name='x_input')
    drop_rate = tf.placeholder(tf.float32, name='drop_rate')
    y_ = tf.placeholder(tf.int64, [None], name='labels')

# %% [markdown]
# ### 4.2 Deifne the LeNet5 object
#
# Use the previously defined LeNet5 class to build LeNet5 network.
# y is the output of the LeNet5 network.

# %%
with tf.name_scope('prediction'):
    le_net5 = LeNet5(x, drop_rate)
    y = le_net5.prediction
# Out:
# conv_1:  (?, 30, 30, 6)
# pool_1:  (?, 30, 30, 6)
# conv_2:  (?, 28, 28, 16)
# pool_2:  (?, 28, 28, 16)
# conv_3: (?, 26, 26, 120)
# flat_1: (?, 81120)
# fc_2  (?, 840)
# fc_3:  (?, 10)
# drop_out:  (?, 10)
# prediction:  (?, 10)

# %% [markdown]
# ### 4.3 Calculate the cross entropy as the loss
# Use the cross entropy as the loss.
# **cross entropy** is normally used as the loss of the network.
# $$cross\_entropy(output, label) = \sum_i{output_i*log(label_i)}$$
#
# tensorflow function **sparse_softmax_cross_entropy_with_logits** calculate the cross entropy with the logits which is one hot output from the network and the label which is a interger number.

# %%
with tf.name_scope('cross_entropy'):
    cross_entropy = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=y,
                                                                          labels=y_, 
                                                                          name="cross_entropy_per_example"))

# %% [markdown]
# ### 4.4 Use Adagrad to minimize the loss

# %%
with tf.name_scope('train_step'):
    train_step = tf.train.AdagradOptimizer(FLAGS.lr).minimize(cross_entropy)

# %% [markdown]
# ### 4.5 Calculate the reduce mean as the accuracy

# %%
with tf.name_scope('train_accuracy'):
    prediction =tf.argmax(y, 1)
    accuracy = tf.reduce_mean(tf.cast( tf.equal(prediction,y_), tf.float32))

# %% [markdown]
# ## Now, let's start the training...

# %%
import time

data = cifar10(data_path);

with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    sess.run(tf.global_variables_initializer())
    saver = tf.train.Saver(max_to_keep=1)
    if CONTINUE != 0:
        model_file=tf.train.latest_checkpoint(ckpt_dir)
        saver.restore(sess,model_file)
    for i in range(CONTINUE, FLAGS.epoch):
        train_image, train_label,_ = data.get_train_batch(FLAGS.batch_size,FLAGS.augument)
        loss, _,accuracy_rate = sess.run([cross_entropy, train_step, accuracy], 
                                         feed_dict={drop_rate: FLAGS.drop_rate, x:train_image, y_:train_label})
        print('.',end='')    
        log.add_log('train_accuracy',i, accuracy_rate)
        log.add_log('train_loss',i, loss)
        if (i+1) % FLAGS.ckpt_frequency == 0:  #保存预测模型
            saver.save(sess,ckpt_dir+'cifar10_'+str(i+1)+'.ckpt',global_step=i+1)
            acc_accuracy = 0
            for j in range(int(10000/FLAGS.test_size)):                    
                test_image, test_label,test_index = data.get_test_batch(FLAGS.test_size)
                accuracy_rate, output = sess.run([accuracy,prediction],
                                                 feed_dict={drop_rate: 0, x:test_image, y_:test_label})
                acc_accuracy += accuracy_rate
                log.add_log('test_index',i, test_index)
                log.add_log('output',i, output)
            accuracy_rate = acc_accuracy/10000*FLAGS.test_size
            print()
            print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()) + 
                  ' iter ' + str(i) + ', Test accuracy:' +str(round(accuracy_rate*100,2))+'%')
            log.add_log('test_accuracy',i, accuracy_rate)
            log.SaveToFile()
    tf.reset_default_graph()
# Out:
# train set length: 50000
# test set length: 10000
# .............................................................................................................................
# 2019-06-19 23:03:41 iter 124, Test accuracy:10.17%
# .............................................................................................................................
# 2019-06-19 23:16:45 iter 249, Test accuracy:12.57%
# .............................................................................................................................
# 2019-06-19 23:30:29 iter 374, Test accuracy:10.57%
# .............................................................................................................................
# 2019-06-19 23:46:53 iter 499, Test accuracy:13.68%
# .............................................................................................................................
# 2019-06-20 00:00:32 iter 624, Test accuracy:19.67%
# .............................................................................................................................
# 2019-06-20 00:13:17 iter 749, Test accuracy:19.57%
# .............................................................................................................................
# 2019-06-20 00:26:42 iter 874, Test accuracy:20.62%
# .............................................................................................................................
# 2019-06-20 00:43:15 iter 999, Test accuracy:20.42%
# .............................................................................................................................
# 2019-06-20 00:57:25 iter 1124, Test accuracy:21.8%
# .............................................................................................................................
# 2019-06-20 01:11:17 iter 1249, Test accuracy:22.16%
# .............................................................................................................................
# 2019-06-20 01:24:45 iter 1374, Test accuracy:22.99%
# .............................................................................................................................
# 2019-06-20 01:40:50 iter 1499, Test accuracy:23.36%
# .............................................................................................................................
# 2019-06-20 01:54:27 iter 1624, Test accuracy:23.34%
# .............................................................................................................................
# 2019-06-20 02:07:42 iter 1749, Test accuracy:24.62%
# .............................................................................................................................
# 2019-06-20 02:31:39 iter 1874, Test accuracy:23.96%
# .............................................................................................................................
# 2019-06-20 03:03:24 iter 1999, Test accuracy:24.44%
# .............................................................................................................................
# 2019-06-20 03:28:11 iter 2124, Test accuracy:25.25%
# .............................................................................................................................
# 2019-06-20 03:55:17 iter 2249, Test accuracy:24.1%
# .............................................................................................................................
# 2019-06-20 04:09:56 iter 2374, Test accuracy:26.06%
# .............................................................................................................................
# 2019-06-20 04:25:56 iter 2499, Test accuracy:26.27%
# .............................................................................................................................
# 2019-06-20 04:39:23 iter 2624, Test accuracy:26.22%
# .............................................................................................................................
# 2019-06-20 04:52:45 iter 2749, Test accuracy:26.67%
# .............................................................................................................................
# 2019-06-20 05:05:44 iter 2874, Test accuracy:26.9%
# .............................................................................................................................
# 2019-06-20 05:22:30 iter 2999, Test accuracy:27.48%
# .............................................................................................................................
# 2019-06-20 05:35:18 iter 3124, Test accuracy:27.03%
# .............................................................................................................................
# 2019-06-20 05:48:22 iter 3249, Test accuracy:27.9%
# .............................................................................................................................
# 2019-06-20 06:01:35 iter 3374, Test accuracy:27.61%
# .............................................................................................................................
# 2019-06-20 06:18:46 iter 3499, Test accuracy:28.22%
# .............................................................................................................................
# 2019-06-20 06:32:24 iter 3624, Test accuracy:27.33%
# .............................................................................................................................
# 2019-06-20 06:45:56 iter 3749, Test accuracy:29.07%
# .............................................................................................................................
# 2019-06-20 06:59:45 iter 3874, Test accuracy:28.77%
# .............................................................................................................................
# 2019-06-20 07:16:05 iter 3999, Test accuracy:29.11%
# .............................................................................................................................
# 2019-06-20 07:29:44 iter 4124, Test accuracy:29.27%
# .............................................................................................................................
# 2019-06-20 07:43:51 iter 4249, Test accuracy:29.11%
# .............................................................................................................................
# 2019-06-20 07:57:16 iter 4374, Test accuracy:30.24%
# .............................................................................................................................
# 2019-06-20 08:14:46 iter 4499, Test accuracy:30.4%
# .............................................................................................................................
# 2019-06-20 08:28:39 iter 4624, Test accuracy:30.2%
# .............................................................................................................................
# 2019-06-20 08:41:56 iter 4749, Test accuracy:30.19%
# .............................................................................................................................
# 2019-06-20 08:55:43 iter 4874, Test accuracy:31.05%
# .............................................................................................................................
# 2019-06-20 09:11:32 iter 4999, Test accuracy:30.64%
# .............................................................................................................................
# 2019-06-20 09:24:49 iter 5124, Test accuracy:31.56%
# .............................................................................................................................
# 2019-06-20 09:38:58 iter 5249, Test accuracy:31.82%
# .............................................................................................................................
# 2019-06-20 09:51:58 iter 5374, Test accuracy:31.5%
# .............................................................................................................................
# 2019-06-20 10:08:49 iter 5499, Test accuracy:32.11%
# .............................................................................................................................
# 2019-06-20 10:21:52 iter 5624, Test accuracy:32.11%
# .............................................................................................................................
# 2019-06-20 10:35:07 iter 5749, Test accuracy:31.52%
# .............................................................................................................................
# 2019-06-20 10:48:31 iter 5874, Test accuracy:32.61%
# .............................................................................................................................
# 2019-06-20 11:05:19 iter 5999, Test accuracy:32.46%
# .............................................................................................................................
# 2019-06-20 11:18:15 iter 6124, Test accuracy:32.74%
# .............................................................................................................................
# 2019-06-20 11:31:17 iter 6249, Test accuracy:32.99%
# .............................................................................................................................
# 2019-06-20 11:44:45 iter 6374, Test accuracy:32.55%
# .............................................................................................................................
# 2019-06-20 12:00:54 iter 6499, Test accuracy:33.01%
# .............................................................................................................................
# 2019-06-20 12:14:37 iter 6624, Test accuracy:32.43%
# .............................................................................................................................
# 2019-06-20 12:27:51 iter 6749, Test accuracy:33.42%
# .............................................................................................................................
# 2019-06-20 12:41:32 iter 6874, Test accuracy:33.57%
# .............................................................................................................................
# 2019-06-20 12:58:22 iter 6999, Test accuracy:32.95%
# .............................................................................................................................
# 2019-06-20 13:12:10 iter 7124, Test accuracy:33.46%
# .............................................................................................................................
# 2019-06-20 13:25:21 iter 7249, Test accuracy:33.25%
# .............................................................................................................................
# 2019-06-20 13:38:44 iter 7374, Test accuracy:33.78%
# .............................................................................................................................
# 2019-06-20 13:54:35 iter 7499, Test accuracy:33.5%
# .............................................................................................................................
# 2019-06-20 14:07:44 iter 7624, Test accuracy:33.62%
# .............................................................................................................................
# 2019-06-20 14:20:56 iter 7749, Test accuracy:34.01%
# .............................................................................................................................
# 2019-06-20 14:34:08 iter 7874, Test accuracy:34.28%
# .............................................................................................................................
# 2019-06-20 14:50:43 iter 7999, Test accuracy:34.8%
# .............................................................................................................................
# 2019-06-20 15:03:37 iter 8124, Test accuracy:33.24%
# .............................................................................................................................
# 2019-06-20 15:16:51 iter 8249, Test accuracy:34.33%
# .............................................................................................................................
# 2019-06-20 15:30:17 iter 8374, Test accuracy:34.95%
# .............................................................................................................................
# 2019-06-20 15:46:41 iter 8499, Test accuracy:34.32%
# .............................................................................................................................
# 2019-06-20 15:59:58 iter 8624, Test accuracy:34.94%
# .............................................................................................................................
# 2019-06-20 16:13:26 iter 8749, Test accuracy:34.85%
# .............................................................................................................................
# 2019-06-20 16:26:28 iter 8874, Test accuracy:35.15%
# .............................................................................................................................
# 2019-06-20 16:43:35 iter 8999, Test accuracy:35.22%
# .............................................................................................................................
# 2019-06-20 16:57:41 iter 9124, Test accuracy:33.82%
# .............................................................................................................................
# 2019-06-20 17:10:42 iter 9249, Test accuracy:35.07%
# .............................................................................................................................
# 2019-06-20 17:24:26 iter 9374, Test accuracy:35.68%
# .............................................................................................................................
# 2019-06-20 17:40:47 iter 9499, Test accuracy:35.07%
# .............................................................................................................................
# 2019-06-20 17:54:17 iter 9624, Test accuracy:34.46%
# .............................................................................................................................
# 2019-06-20 18:07:14 iter 9749, Test accuracy:35.0%
# .............................................................................................................................
# 2019-06-20 18:20:56 iter 9874, Test accuracy:35.99%
# .............................................................................................................................
# 2019-06-20 18:37:22 iter 9999, Test accuracy:36.12%
# .............................................................................................................................
# 2019-06-20 18:51:37 iter 10124, Test accuracy:36.57%
# .............................................................................................................................
# 2019-06-20 19:05:37 iter 10249, Test accuracy:36.12%
# .............................................................................................................................
# 2019-06-20 19:18:42 iter 10374, Test accuracy:36.04%
# .............................................................................................................................
# 2019-06-20 19:34:51 iter 10499, Test accuracy:36.31%
# .............................................................................................................................
# 2019-06-20 19:48:16 iter 10624, Test accuracy:35.92%
# .............................................................................................................................
# 2019-06-20 20:01:35 iter 10749, Test accuracy:36.41%
# .............................................................................................................................
# 2019-06-20 20:15:13 iter 10874, Test accuracy:36.56%
# .............................................................................................................................
# 2019-06-20 20:32:26 iter 10999, Test accuracy:36.68%
# .............................................................................................................................
# 2019-06-20 20:46:05 iter 11124, Test accuracy:36.21%
# .............................................................................................................................
# 2019-06-20 20:59:36 iter 11249, Test accuracy:36.25%
# .............................................................................................................................
# 2019-06-20 21:13:41 iter 11374, Test accuracy:36.55%
# .............................................................................................................................
# 2019-06-20 21:31:32 iter 11499, Test accuracy:36.08%
# .............................................................................................................................
# 2019-06-20 21:44:45 iter 11624, Test accuracy:35.95%
# .............................................................................................................................
# 2019-06-20 21:57:42 iter 11749, Test accuracy:37.12%
# .............................................................................................................................
# 2019-06-20 22:11:27 iter 11874, Test accuracy:37.14%
# .............................................................................................................................
# 2019-06-20 22:27:00 iter 11999, Test accuracy:37.66%
# .............................................................................................................................
# 2019-06-20 22:39:52 iter 12124, Test accuracy:37.31%
# .............................................................................................................................
# 2019-06-20 22:53:23 iter 12249, Test accuracy:37.68%
# .............................................................................................................................
# 2019-06-20 23:06:57 iter 12374, Test accuracy:36.95%
# .............................................................................................................................
# 2019-06-20 23:23:04 iter 12499, Test accuracy:37.91%
# .............................................................................................................................
# 2019-06-20 23:35:52 iter 12624, Test accuracy:37.42%
# .............................................................................................................................
# 2019-06-20 23:48:51 iter 12749, Test accuracy:37.47%
# .............................................................................................................................
# 2019-06-21 00:02:18 iter 12874, Test accuracy:37.62%
# .............................................................................................................................
# 2019-06-21 00:18:55 iter 12999, Test accuracy:37.97%
# .............................................................................................................................
# 2019-06-21 00:32:41 iter 13124, Test accuracy:36.72%
# .............................................................................................................................
# 2019-06-21 00:45:45 iter 13249, Test accuracy:37.97%
# .............................................................................................................................
# 2019-06-21 00:59:08 iter 13374, Test accuracy:38.32%
# .............................................................................................................................
# 2019-06-21 01:16:35 iter 13499, Test accuracy:37.85%
# .............................................................................................................................
# 2019-06-21 01:30:07 iter 13624, Test accuracy:38.31%
# .............................................................................................................................
# 2019-06-21 01:43:08 iter 13749, Test accuracy:37.86%
# .............................................................................................................................
# 2019-06-21 01:56:43 iter 13874, Test accuracy:37.92%
# .............................................................................................................................
# 2019-06-21 02:12:43 iter 13999, Test accuracy:38.38%
# .............................................................................................................................
# 2019-06-21 02:25:54 iter 14124, Test accuracy:38.67%
# .............................................................................................................................
# 2019-06-21 02:39:21 iter 14249, Test accuracy:38.1%
# .............................................................................................................................
# 2019-06-21 02:52:35 iter 14374, Test accuracy:38.26%
# .............................................................................................................................
# 2019-06-21 03:08:34 iter 14499, Test accuracy:38.12%
# .............................................................................................................................
# 2019-06-21 03:21:33 iter 14624, Test accuracy:38.44%
# .............................................................................................................................
# 2019-06-21 03:34:36 iter 14749, Test accuracy:38.2%
# .............................................................................................................................
# 2019-06-21 03:48:18 iter 14874, Test accuracy:38.15%
# .............................................................................................................................
# 2019-06-21 04:04:35 iter 14999, Test accuracy:37.69%
# .............................................................................................................................
# 2019-06-21 04:18:29 iter 15124, Test accuracy:38.67%
# .............................................................................................................................
# 2019-06-21 04:31:24 iter 15249, Test accuracy:38.1%
# .............................................................................................................................
# 2019-06-21 04:44:36 iter 15374, Test accuracy:39.02%
# .............................................................................................................................
# 2019-06-21 05:00:43 iter 15499, Test accuracy:39.26%
# .............................................................................................................................
# 2019-06-21 05:13:30 iter 15624, Test accuracy:39.03%
# .............................................................................................................................
# 2019-06-21 05:26:36 iter 15749, Test accuracy:39.14%
# .............................................................................................................................
# 2019-06-21 05:40:39 iter 15874, Test accuracy:38.02%
# .............................................................................................................................
# 2019-06-21 05:56:46 iter 15999, Test accuracy:38.79%
# .............................................................................................................................
# 2019-06-21 06:10:14 iter 16124, Test accuracy:38.42%
# .............................................................................................................................
# 2019-06-21 06:23:47 iter 16249, Test accuracy:39.39%
# .............................................................................................................................
# 2019-06-21 06:37:13 iter 16374, Test accuracy:38.59%
# .............................................................................................................................
# 2019-06-21 06:53:43 iter 16499, Test accuracy:38.07%
# .............................................................................................................................
# 2019-06-21 07:06:30 iter 16624, Test accuracy:39.49%
# .............................................................................................................................
# 2019-06-21 07:20:08 iter 16749, Test accuracy:39.38%
# .............................................................................................................................
# 2019-06-21 07:33:57 iter 16874, Test accuracy:39.31%
# .............................................................................................................................
# 2019-06-21 07:49:59 iter 16999, Test accuracy:38.62%
# .............................................................................................................................
# 2019-06-21 08:03:20 iter 17124, Test accuracy:38.48%
# .............................................................................................................................
# 2019-06-21 08:16:10 iter 17249, Test accuracy:39.66%
# .............................................................................................................................
# 2019-06-21 08:29:36 iter 17374, Test accuracy:39.43%
# .............................................................................................................................
# 2019-06-21 08:48:08 iter 17499, Test accuracy:38.8%
# .............................................................................................................................
# 2019-06-21 09:01:24 iter 17624, Test accuracy:40.0%
# .............................................................................................................................
# 2019-06-21 09:14:50 iter 17749, Test accuracy:40.01%
# .............................................................................................................................
# 2019-06-21 09:28:30 iter 17874, Test accuracy:40.34%
# .............................................................................................................................
# 2019-06-21 09:44:52 iter 17999, Test accuracy:39.94%
# .............................................................................................................................
# 2019-06-21 09:57:58 iter 18124, Test accuracy:40.32%
# .............................................................................................................................
# 2019-06-21 10:11:16 iter 18249, Test accuracy:38.71%
# .............................................................................................................................
# 2019-06-21 10:24:58 iter 18374, Test accuracy:39.55%
# .............................................................................................................................
# 2019-06-21 10:41:16 iter 18499, Test accuracy:39.97%
# .............................................................................................................................
# 2019-06-21 10:54:46 iter 18624, Test accuracy:40.54%
# .............................................................................................................................
# 2019-06-21 11:08:20 iter 18749, Test accuracy:39.94%
# .............................................................................................................................
# 2019-06-21 11:22:00 iter 18874, Test accuracy:40.18%
# .............................................................................................................................
# 2019-06-21 11:38:11 iter 18999, Test accuracy:39.4%
# .............................................................................................................................
# 2019-06-21 11:52:56 iter 19124, Test accuracy:38.06%
# .............................................................................................................................
# 2019-06-21 12:06:06 iter 19249, Test accuracy:40.92%
# .............................................................................................................................
# 2019-06-21 12:19:29 iter 19374, Test accuracy:40.65%
# .............................................................................................................................
# 2019-06-21 12:36:19 iter 19499, Test accuracy:41.8%
# .............................................................................................................................
# 2019-06-21 12:49:03 iter 19624, Test accuracy:41.88%
# .............................................................................................................................
# 2019-06-21 13:02:13 iter 19749, Test accuracy:41.09%
# .............................................................................................................................
# 2019-06-21 13:15:21 iter 19874, Test accuracy:42.82%
# .............................................................................................................................
# 2019-06-21 13:32:15 iter 19999, Test accuracy:43.27%
# .............................................................................................................................
# 2019-06-21 13:46:06 iter 20124, Test accuracy:42.8%
# .............................................................................................................................
# 2019-06-21 13:59:31 iter 20249, Test accuracy:40.42%
# .............................................................................................................................
# 2019-06-21 14:12:42 iter 20374, Test accuracy:42.87%
# .............................................................................................................................
# 2019-06-21 14:29:30 iter 20499, Test accuracy:42.78%
# .............................................................................................................................
# 2019-06-21 14:42:46 iter 20624, Test accuracy:41.66%
# .............................................................................................................................
# 2019-06-21 14:57:04 iter 20749, Test accuracy:42.61%
# ......................................................................................................
# 2019-06-21 15:10:00 iter 20874, Test accuracy:42.73%
# .............................................................................................................................
# 2019-06-21 15:26:46 iter 20999, Test accuracy:44.23%
# .............................................................................................................................
# 2019-06-21 15:40:09 iter 21124, Test accuracy:42.01%
# .............................................................................................................................
# 2019-06-21 15:53:33 iter 21249, Test accuracy:43.88%
# .............................................................................................................................
# 2019-06-21 16:06:58 iter 21374, Test accuracy:43.07%
# .............................................................................................................................
# 2019-06-21 16:23:07 iter 21499, Test accuracy:42.96%
# .............................................................................................................................
# 2019-06-21 16:36:26 iter 21624, Test accuracy:43.73%
# .............................................................................................................................
# 2019-06-21 16:49:43 iter 21749, Test accuracy:43.55%
# .............................................................................................................................
# 2019-06-21 17:02:59 iter 21874, Test accuracy:44.08%
# .............................................................................................................................
# 2019-06-21 17:20:13 iter 21999, Test accuracy:43.02%
# .............................................................................................................................
# 2019-06-21 17:33:41 iter 22124, Test accuracy:42.59%
# .............................................................................................................................
# 2019-06-21 17:46:40 iter 22249, Test accuracy:43.39%
# .............................................................................................................................
# 2019-06-21 18:00:03 iter 22374, Test accuracy:43.98%
# .............................................................................................................................
# 2019-06-21 18:17:21 iter 22499, Test accuracy:43.33%
# .............................................................................................................................
# 2019-06-21 18:31:16 iter 22624, Test accuracy:43.95%
# .............................................................................................................................
# 2019-06-21 18:44:22 iter 22749, Test accuracy:43.1%
# .............................................................................................................................
# 2019-06-21 18:57:43 iter 22874, Test accuracy:43.63%
# .............................................................................................................................
# 2019-06-21 19:14:06 iter 22999, Test accuracy:44.34%
# .............................................................................................................................
# 2019-06-21 19:27:12 iter 23124, Test accuracy:42.62%
# .............................................................................................................................
# 2019-06-21 19:40:12 iter 23249, Test accuracy:43.9%
# .............................................................................................................................
# 2019-06-21 19:54:01 iter 23374, Test accuracy:43.69%
# .............................................................................................................................
# 2019-06-21 20:11:01 iter 23499, Test accuracy:44.17%
# .............................................................................................................................
# 2019-06-21 20:25:11 iter 23624, Test accuracy:44.55%
# .............................................................................................................................
# 2019-06-21 20:38:16 iter 23749, Test accuracy:43.04%
# .............................................................................................................................
# 2019-06-21 20:51:09 iter 23874, Test accuracy:44.1%
# .............................................................................................................................
# 2019-06-21 21:08:02 iter 23999, Test accuracy:44.7%
# .............................................................................................................................
# 2019-06-21 21:20:55 iter 24124, Test accuracy:44.6%
# .............................................................................................................................
# 2019-06-21 21:34:59 iter 24249, Test accuracy:43.39%
# .............................................................................................................................
# 2019-06-21 21:48:11 iter 24374, Test accuracy:44.03%
# .............................................................................................................................
# 2019-06-21 22:04:23 iter 24499, Test accuracy:44.19%
# .............................................................................................................................
# 2019-06-21 22:17:29 iter 24624, Test accuracy:44.28%
# .............................................................................................................................
# 2019-06-21 22:31:21 iter 24749, Test accuracy:43.98%
# .............................................................................................................................
# 2019-06-21 22:44:46 iter 24874, Test accuracy:44.75%
# .............................................................................................................................
# 2019-06-21 23:00:49 iter 24999, Test accuracy:44.68%
# .............................................................................................................................
# 2019-06-21 23:14:31 iter 25124, Test accuracy:43.15%
# .............................................................................................................................
# 2019-06-21 23:27:38 iter 25249, Test accuracy:44.32%
# .............................................................................................................................
# 2019-06-21 23:41:08 iter 25374, Test accuracy:43.9%
# .............................................................................................................................
# 2019-06-21 23:57:27 iter 25499, Test accuracy:44.73%
# .............................................................................................................................
# 2019-06-22 00:10:38 iter 25624, Test accuracy:44.89%
# .............................................................................................................................
# 2019-06-22 00:23:56 iter 25749, Test accuracy:43.59%
# .............................................................................................................................
# 2019-06-22 00:37:38 iter 25874, Test accuracy:44.14%
# .............................................................................................................................
# 2019-06-22 00:54:14 iter 25999, Test accuracy:45.01%
# .............................................................................................................................
# 2019-06-22 01:07:21 iter 26124, Test accuracy:45.18%
# .............................................................................................................................
# 2019-06-22 01:20:33 iter 26249, Test accuracy:44.68%
# .............................................................................................................................
# 2019-06-22 01:34:07 iter 26374, Test accuracy:45.25%
# .............................................................................................................................
# 2019-06-22 01:50:42 iter 26499, Test accuracy:46.08%
# .............................................................................................................................
# 2019-06-22 02:03:32 iter 26624, Test accuracy:46.14%
# .............................................................................................................................
# 2019-06-22 02:16:39 iter 26749, Test accuracy:45.64%
# .............................................................................................................................
# 2019-06-22 02:30:22 iter 26874, Test accuracy:44.3%
# .............................................................................................................................
# 2019-06-22 02:47:10 iter 26999, Test accuracy:45.51%
# .............................................................................................................................
# 2019-06-22 03:00:44 iter 27124, Test accuracy:45.05%
# .............................................................................................................................
# 2019-06-22 03:15:03 iter 27249, Test accuracy:45.59%
# .............................................................................................................................
# 2019-06-22 03:28:40 iter 27374, Test accuracy:44.91%
# .............................................................................................................................
# 2019-06-22 03:44:28 iter 27499, Test accuracy:46.11%
# .............................................................................................................................
# 2019-06-22 03:57:32 iter 27624, Test accuracy:45.38%
# .............................................................................................................................
# 2019-06-22 04:10:39 iter 27749, Test accuracy:45.19%
# .............................................................................................................................
# 2019-06-22 04:24:04 iter 27874, Test accuracy:46.16%
# .............................................................................................................................
# 2019-06-22 04:41:26 iter 27999, Test accuracy:44.59%
# .............................................................................................................................
# 2019-06-22 04:54:30 iter 28124, Test accuracy:45.43%
# .............................................................................................................................
# 2019-06-22 05:08:19 iter 28249, Test accuracy:45.68%
# .............................................................................................................................
# 2019-06-22 05:21:33 iter 28374, Test accuracy:44.84%
# .............................................................................................................................
# 2019-06-22 05:37:58 iter 28499, Test accuracy:46.75%
# .............................................................................................................................
# 2019-06-22 05:51:18 iter 28624, Test accuracy:45.67%
# .............................................................................................................................
# 2019-06-22 06:04:40 iter 28749, Test accuracy:45.77%
# .............................................................................................................................
# 2019-06-22 06:18:06 iter 28874, Test accuracy:45.29%
# .............................................................................................................................
# 2019-06-22 06:34:15 iter 28999, Test accuracy:45.39%
# .............................................................................................................................
# 2019-06-22 06:47:39 iter 29124, Test accuracy:45.57%
# .............................................................................................................................
# 2019-06-22 07:00:47 iter 29249, Test accuracy:46.21%
# .............................................................................................................................
# 2019-06-22 07:14:14 iter 29374, Test accuracy:46.56%
# .............................................................................................................................
# 2019-06-22 07:30:38 iter 29499, Test accuracy:45.88%
# .............................................................................................................................
# 2019-06-22 07:44:28 iter 29624, Test accuracy:46.2%
# .............................................................................................................................
# 2019-06-22 07:57:44 iter 29749, Test accuracy:46.51%
# .............................................................................................................................
# 2019-06-22 08:11:30 iter 29874, Test accuracy:45.14%
# .............................................................................................................................
# 2019-06-22 08:28:21 iter 29999, Test accuracy:46.09%
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-c52e66b42771> in <module>()
#      32             log.add_log('test_accuracy',i, accuracy_rate)
#      33             log.SaveToFile()
# ---> 34     tf.reset_default_graph()
#
# ~/anaconda3/envs/python3-tensorflow/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in reset_default_graph()
#    5301   """
#    5302   if not _default_graph_stack.is_cleared():
# -> 5303     raise AssertionError("Do not use tf.reset_default_graph() to clear "
#    5304                          "nested graphs. If you need a cleared graph, "
#    5305                          "exit the nesting and create a new graph.")
#
# AssertionError: Do not use tf.reset_default_graph() to clear nested graphs. If you need a cleared graph, exit the nesting and create a new graph.
